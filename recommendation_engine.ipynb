# %% [markdown]
# ### Run Dependencies

# %%
# %run ./utils.ipynb

# %% [markdown]
# ### Invoke Recommendation Engine

# %%
recommender = RecommendationEngine()

# %% [markdown]
# ### Run Recommendations

# %%
recommender.execute_pipeline()
# Out:
# Running loop:  0 / 2536 customer profiles completed
# Running loop:  1 / 2536 customer profiles completed
# Running loop:  2 / 2536 customer profiles completed
# Running loop:  3 / 2536 customer profiles completed
# Running loop:  4 / 2536 customer profiles completed
# Running loop:  5 / 2536 customer profiles completed
# Running loop:  6 / 2536 customer profiles completed
# Running loop:  7 / 2536 customer profiles completed
# Running loop:  8 / 2536 customer profiles completed
# Running loop:  9 / 2536 customer profiles completed
# Running loop:  10 / 2536 customer profiles completed
# Running loop:  11 / 2536 customer profiles completed
# Running loop:  12 / 2536 customer profiles completed
# Running loop:  13 / 2536 customer profiles completed
# Running loop:  14 / 2536 customer profiles completed
# Running loop:  15 / 2536 customer profiles completed
# Running loop:  16 / 2536 customer profiles completed
# Running loop:  17 / 2536 customer profiles completed
# ...
